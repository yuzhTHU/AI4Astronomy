# %%
import os

if os.getcwd().endswith("scripts"):
    os.chdir("..")
os.getcwd()
# Out:
# '/mnt/mergerfs/yuzihan/MergedWorkSpace/44-AI4Astronomy/AI4Astronomy'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sr_agent.utils.plot import get_fig

# %%
df = pd.read_csv('data/blinkverse/analysis_single.flattened.csv')
df.describe()
# Out:
#             data_id       dm_snr           mjd      rm_qufit      scin_f  \
# count  16335.000000  4099.000000  10779.000000   1720.000000  129.000000
# mean    8176.777227   487.003077  59305.077557   -311.183057    3.993512
# std     4721.586813   274.664066    986.871905   1261.034398    6.117414
# min        1.000000    64.000000  50596.337996 -24034.500000  -13.220000
# 25%     4085.500000   351.135000  58752.879343   -603.697250    0.755000
# 50%     8180.000000   412.970000  59347.301722   -508.538000    4.206000
# 75%    12263.500000   560.500000  59890.170384      1.100000    7.527000
# max    16347.000000  3038.058000  60705.214567  12523.000000   25.462000
#
#             mjd_inf      mjd_topo  mjd_topo_atGHz            gl            gb  \
# count  15553.000000   8479.000000    12308.000000  16211.000000  16211.000000
# mean   59300.047663  59202.855063      170.335999    182.425700     11.498018
# ...
